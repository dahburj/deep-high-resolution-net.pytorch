# %% [markdown]
# # Install Pytorch

# %%
# !pip3 install tensorboardX==1.6

# %%
# !pip3 install https://download.pytorch.org/whl/cu100/torch-1.1.0-cp36-cp36m-linux_x86_64.whl
# !pip3 install https://download.pytorch.org/whl/cu100/torchvision-0.3.0-cp36-cp36m-linux_x86_64.whl

# %% [markdown]
# # Link Google Drive

# %%
#Now, let's link to your GoogleDrive. Run this cell and follow the authorization instructions:
#(We recommend putting a copy of the github repo in your google drive if you are using the demo "examples")

from google.colab import drive
drive.mount('/content/drive')

# %%
#GUIs don't work on the cloud, so we will supress wxPython: 
import os
os.environ["DLClight"]="True"
os.environ["Colab"]="True"

# %% [markdown]
# #Navigate to your deep-high-res-net directory in gdrive and install requirements

# %%
#Be sure you have a copy of your project folder in your Google Drive. Then, let's go to your project folder!
# %cd '/content/drive/My Drive/AI-Projects/deep-high-resolution-net.pytorch'
# !pip3 install -r requirements.txt

# %%
# %cd lib
# !make

# %%
# %cd ..
# %cd cocoapi/PythonAPI
# !python3 setup.py install --user

# %%
# %cd ..
# %cd ..
# !ls

# %% [markdown]
# # Run Training

# %%
# !python3 tools/train.py \
    --cfg experiments/mpii/hrnet/w32_256x256_adam_lr1e-3.yaml
